# %%
import pandas as pd

# %%
df = pd.read_csv("finaldata.json")

# %%
df
# Out:
#      CompanyName           Location                            center  \
# 0         SpaceX             LC-39A              Kennedy Space Center
# 1          CASIC  Site 9401 (SLS-2)   Jiuquan Satellite Launch Center
# 2         SpaceX              Pad A                        Boca Chica
# 3      Roscosmos        Site 200/39               Baikonur Cosmodrome
# 4            ULA             SLC-41                Cape Canaveral AFS
# ...          ...                ...                               ...
# 4319     US Navy             LC-18A                Cape Canaveral AFS
# 4320        AMBA             LC-26A                Cape Canaveral AFS
# 4321     US Navy             LC-18A                Cape Canaveral AFS
# 4322   RVSN USSR           Site 1/5               Baikonur Cosmodrome
# 4323   RVSN USSR           Site 1/5               Baikonur Cosmodrome
#
#       Lantitude   longitude     state CountryofLaunch Rocket  \
# 0     28.524167  -80.650833   Florida             USA     50
# ...

# %%
column_names = ['name', 'value', 'year', 'lastValue', 'rank']
